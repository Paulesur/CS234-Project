# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import viz

COLORS, PAGE_WIDTH, ROW_HEIGHT = viz.set_plots("notebook")

# %%
from scipy.stats import beta

# Parameters for the beta distribution
a,b = 5,3

# Generate a beta distribution
x = np.linspace(0, 1, 1000)
t = np.linspace(0,360,360)
y = beta.pdf(x, a, b) / 

# Plot the beta distribution
plt.plot(x, y)
plt.title('Beta Distribution')
plt.xlabel('Hour of the day')
plt.ylabel(r'$soc_t$')
plt.show()

# %%
draw = 
draw
# Out:
# array([0.22216157])

# %%
# Out:
# array([0.25939378])

# %%
import pandas as pd

# Load the data
prices = pd.read_csv('prices.csv', index_col=0, parse_dates=True)

# %%
prices.lmp.rolling(24).std().plot()
# Out:
# <Axes: xlabel='interval_start_local'>

# %%
for i in range(100):
    k = np.random.randint(0, len(prices)//24)
    plt.plot(np.arange(24),prices.iloc[k*24:(k+1)*24].lmp)
plt.show()

# %%
plt.hist(prices.lmp, density=True, bins=100)
# Out:
# (array([4.17601331e-05, 2.44655325e-04, 2.49527341e-03, 1.48682947e-02,
#         1.12520359e-02, 4.38607943e-03, 1.59616509e-03, 7.10554992e-04,
#         3.80059393e-04, 2.17447966e-04, 1.52487759e-04, 1.08407618e-04,
#         8.75275517e-05, 6.51711168e-05, 6.36947484e-05, 4.64001479e-05,
#         2.95273668e-05, 2.44655325e-05, 2.13018861e-05, 1.51855029e-05,
#         1.26545858e-05, 1.20218565e-05, 6.53820265e-06, 8.85821005e-06,
#         4.21819526e-06, 6.74911242e-06, 4.00728550e-06, 2.95273668e-06,
#         3.37455621e-06, 2.95273668e-06, 2.74182692e-06, 2.32000739e-06,
#         1.68727810e-06, 2.95273668e-06, 1.89818787e-06, 2.53091716e-06,
#         2.10909763e-06, 2.10909763e-06, 2.53091716e-06, 8.22548076e-06,
#         7.17093194e-06, 5.27274408e-06, 3.37455621e-06, 1.68727810e-06,
#         1.47636834e-06, 6.32729289e-07, 6.32729289e-07, 6.32729289e-07,
#         1.05454882e-06, 0.00000000e+00, 1.05454882e-06, 2.10909763e-06,
# ...
